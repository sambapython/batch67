# %%
f= open("data.txt","w")

# %%
f.write("x=1000,y=2000")
# Out:
# 13

# %%
f.close()

# %%
f.write(",z=300")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-eee7f8f179e1> in <module>
# ----> 1 f.write(",z=300")
#
# ValueError: I/O operation on closed file.

# %%
f= open("data.txt","w")

# %%
f.write("sfsd")
# Out:
# 4

# %%
f.flush()

# %%
f.write("\nx=100,y=200")
# Out:
# 12

# %%
f.flush()

# %%
f= open("data.txt","w")

# %%
f.write("dasdfsdf")
f.writelines(["sdfsd","sdfsd","sdfdsf"])
f.close()

# %%
f= open("data.txt","a")
f.write("\n added text in append mode")
f.close()

# %%
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
f=open("data.txt","w")
f.write(persons)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e872f1280612> in <module>
#       1 persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
#       2 f=open("data.txt","w")
# ----> 3 f.write(persons)
#       4 f.close()
#
# TypeError: write() argument must be str, not list

# %%
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
f=open("data.txt","w")
f.writelines(persons)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-674bd888c6bc> in <module>
#       1 persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
#       2 f=open("data.txt","w")
# ----> 3 f.writelines(persons)
#       4 f.close()
#
# TypeError: write() argument must be str, not dict

# %%
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
f=open("data.txt","w")
f.write(str(persons))
f.close()

# %%
f=open("data.txt","r")
data = f.read()
print(data,type(data))
# Out:
# [{'name': 'jay', 'age': 3}, {'name': 'vedha', 'age': 2}, {'name': 'dhana', 'age': 18}] <class 'str'>

# %%
import pickle
f=open("data.txt","wb")
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
pickle.dump(persons,f)
f.close()

# %%
f=open("data.txt","rb")
data=pickle.load(f)
print(data,type(data))
# Out:
# [{'name': 'jay', 'age': 3}, {'name': 'vedha', 'age': 2}, {'name': 'dhana', 'age': 18}] <class 'list'>

# %%
import random
f=open("data.csv","w")
f.write("name,address,sal,id")
names=["samba","venkatesh","amar","sai","priyanka"]
random.choice(names)
# Out:
# 'venkatesh'

# %%
import random
f=open("data.csv","w")
f.write("name,address,sal,id")
names=["samba","venkatesh","amar","sai","priyanka"]
random.choice(names)
# Out:
# 'samba'

# %%
import random
f=open("data.csv","w")
f.write("name,address,sal,id\n")
names=["samba","venkatesh","amar","sai","priyanka"]
addresses = ["devender nagar","ameerpet","uppal","sr nagar","KPHB"]
sals = range(50000,90000)
for i in range(1000):
    row = "%s,%s,%s,%s\n"%(random.choice(names),
                        random.choice(addresses),
                        random.choice(sals),i)
    f.write(row)
f.close()

# %%
import random
f=open("data.csv","w")
f.write("name,address,sal,id\n")
names=["samba","venkatesh","amar","sai","priyanka"]
addresses = ["devender nagar","ameerpet","uppal","sr nagar","KPHB"]
sals = range(50000,90000)
for i in range(1000):
    row = "%s,%s,%s,%s\n"%(random.choice(names),
                        random.choice(addresses),
                        random.choice(sals),i)
    f.write(row)
    f.flush()
f.close()

# %%
f=open("data.csv","r")
data=f.read()
print(data)
# Out:
# name,address,sal,id
# sai,ameerpet,50735,0
# venkatesh,ameerpet,59921,1
# venkatesh,KPHB,61532,2
# samba,devender nagar,55481,3
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,ameerpet,69280,7
# venkatesh,sr nagar,88184,8
# venkatesh,KPHB,78754,9
# priyanka,KPHB,72143,10
# sai,uppal,69439,11
# venkatesh,sr nagar,60704,12
# venkatesh,ameerpet,77010,13
# venkatesh,sr nagar,76201,14
# amar,ameerpet,50280,15
# sai,devender nagar,60386,16
# amar,KPHB,88387,17
# priyanka,devender nagar,84606,18
# priyanka,devender nagar,87318,19
# samba,KPHB,86656,20
# sai,sr nagar,52393,21
# venkatesh,devender nagar,77989,22
# samba,devender nagar,62932,23
# sai,sr nagar,77047,24
# samba,devender nagar,86786,25
# venkatesh,devender nagar,68756,26
# samba,sr nagar,65534,27
# samba,sr nagar,59173,28
# amar,KPHB,56054,29
# venkatesh,devender nagar,88017,30
# amar,sr nagar,51838,31
# priyanka,sr nagar,52899,32
# samba,KPHB,52593,33
# priyanka,sr nagar,86597,34
# ...

# %%
25/(1024*1024)
# Out:
# 2.384185791015625e-05

# %%
a=0.0000023
x=1000
y=0.0000023
y=40
x?

# %%
f=open("data.csv")
data = f.readlines()
print(data)
# Out:
# ['name,address,sal,id\n', 'sai,ameerpet,50735,0\n', 'venkatesh,ameerpet,59921,1\n', 'venkatesh,KPHB,61532,2\n', 'samba,devender nagar,55481,3\n', 'amar,ameerpet,82344,4\n', 'venkatesh,ameerpet,59019,5\n', 'sai,KPHB,74974,6\n', 'venkatesh,ameerpet,69280,7\n', 'venkatesh,sr nagar,88184,8\n', 'venkatesh,KPHB,78754,9\n', 'priyanka,KPHB,72143,10\n', 'sai,uppal,69439,11\n', 'venkatesh,sr nagar,60704,12\n', 'venkatesh,ameerpet,77010,13\n', 'venkatesh,sr nagar,76201,14\n', 'amar,ameerpet,50280,15\n', 'sai,devender nagar,60386,16\n', 'amar,KPHB,88387,17\n', 'priyanka,devender nagar,84606,18\n', 'priyanka,devender nagar,87318,19\n', 'samba,KPHB,86656,20\n', 'sai,sr nagar,52393,21\n', 'venkatesh,devender nagar,77989,22\n', 'samba,devender nagar,62932,23\n', 'sai,sr nagar,77047,24\n', 'samba,devender nagar,86786,25\n', 'venkatesh,devender nagar,68756,26\n', 'samba,sr nagar,65534,27\n', 'samba,sr nagar,59173,28\n', 'amar,KPHB,56054,29\n', 'venkatesh,devender nagar,88017,30\n', 'amar,sr nagar,5183
# ...

# %%
f=open("data.csv")
data = f.readline()
print(data)
data1=f.readline()
print(data1)
# Out:
# name,address,sal,id
#
# sai,ameerpet,50735,0

# %%
f.readline()
# Out:
# 'venkatesh,ameerpet,59921,1\n'

# %%
print(f.readline())
# Out:
# samba,devender nagar,55481,3

# %%
data=f.read()

# %%
print(data[:100])
# Out:
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,ameerpet,69280,7
# venkate

# %%
print(data)
# Out:
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,ameerpet,69280,7
# venkatesh,sr nagar,88184,8
# venkatesh,KPHB,78754,9
# priyanka,KPHB,72143,10
# sai,uppal,69439,11
# venkatesh,sr nagar,60704,12
# venkatesh,ameerpet,77010,13
# venkatesh,sr nagar,76201,14
# amar,ameerpet,50280,15
# sai,devender nagar,60386,16
# amar,KPHB,88387,17
# priyanka,devender nagar,84606,18
# priyanka,devender nagar,87318,19
# samba,KPHB,86656,20
# sai,sr nagar,52393,21
# venkatesh,devender nagar,77989,22
# samba,devender nagar,62932,23
# sai,sr nagar,77047,24
# samba,devender nagar,86786,25
# venkatesh,devender nagar,68756,26
# samba,sr nagar,65534,27
# samba,sr nagar,59173,28
# amar,KPHB,56054,29
# venkatesh,devender nagar,88017,30
# amar,sr nagar,51838,31
# priyanka,sr nagar,52899,32
# samba,KPHB,52593,33
# priyanka,sr nagar,86597,34
# amar,devender nagar,59738,35
# priyanka,devender nagar,75944,36
# amar,sr nagar,79227,37
# venkatesh,uppal,59085,38
# ...

# %%
data=f.read()
print(data)

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.tell())
# Out:
# 0

# %%
data=f.read()
print(data)
# Out:
# name,address,sal,id
# sai,ameerpet,50735,0
# venkatesh,ameerpet,59921,1
# venkatesh,KPHB,61532,2
# samba,devender nagar,55481,3
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,ameerpet,69280,7
# venkatesh,sr nagar,88184,8
# venkatesh,KPHB,78754,9
# priyanka,KPHB,72143,10
# sai,uppal,69439,11
# venkatesh,sr nagar,60704,12
# venkatesh,ameerpet,77010,13
# venkatesh,sr nagar,76201,14
# amar,ameerpet,50280,15
# sai,devender nagar,60386,16
# amar,KPHB,88387,17
# priyanka,devender nagar,84606,18
# priyanka,devender nagar,87318,19
# samba,KPHB,86656,20
# sai,sr nagar,52393,21
# venkatesh,devender nagar,77989,22
# samba,devender nagar,62932,23
# sai,sr nagar,77047,24
# samba,devender nagar,86786,25
# venkatesh,devender nagar,68756,26
# samba,sr nagar,65534,27
# samba,sr nagar,59173,28
# amar,KPHB,56054,29
# venkatesh,devender nagar,88017,30
# amar,sr nagar,51838,31
# priyanka,sr nagar,52899,32
# samba,KPHB,52593,33
# priyanka,sr nagar,86597,34
# ...

# %%
print(f.tell())
# Out:
# 25505

# %%
f=open("data.csv")
data=f.read(100)
print(data)
print("*"*20)
data1 = f.read(100)
print(data1)
# Out:
# name,address,sal,id
# sai,ameerpet,50735,0
# venkatesh,ameerpet,59921,1
# venkatesh,KPHB,61532,2
# samba,dev
# ********************
# ender nagar,55481,3
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,amee

# %%
f=open("data.csv")
while 1:
    data = f.read(100)
    if not data:
        break
    print(data)
# Out:
# name,address,sal,id
# sai,ameerpet,50735,0
# venkatesh,ameerpet,59921,1
# venkatesh,KPHB,61532,2
# samba,dev
# ender nagar,55481,3
# amar,ameerpet,82344,4
# venkatesh,ameerpet,59019,5
# sai,KPHB,74974,6
# venkatesh,amee
# rpet,69280,7
# venkatesh,sr nagar,88184,8
# venkatesh,KPHB,78754,9
# priyanka,KPHB,72143,10
# sai,uppal,6943
# 9,11
# venkatesh,sr nagar,60704,12
# venkatesh,ameerpet,77010,13
# venkatesh,sr nagar,76201,14
# amar,ameerp
# et,50280,15
# sai,devender nagar,60386,16
# amar,KPHB,88387,17
# priyanka,devender nagar,84606,18
# priyanka
# ,devender nagar,87318,19
# samba,KPHB,86656,20
# sai,sr nagar,52393,21
# venkatesh,devender nagar,77989,22
#
# samba,devender nagar,62932,23
# sai,sr nagar,77047,24
# samba,devender nagar,86786,25
# venkatesh,devende
# r nagar,68756,26
# samba,sr nagar,65534,27
# samba,sr nagar,59173,28
# amar,KPHB,56054,29
# venkatesh,devend
# er nagar,88017,30
# amar,sr nagar,51838,31
# priyanka,sr nagar,52899,32
# samba,KPHB,52593,33
# priyanka,sr
# ...

# %%
f=open("data.csv")
while 1:
    data = f.readline()
    if not data:
        break
    print(data)
# Out:
# name,address,sal,id
#
# sai,ameerpet,50735,0
#
# venkatesh,ameerpet,59921,1
#
# venkatesh,KPHB,61532,2
#
# samba,devender nagar,55481,3
#
# amar,ameerpet,82344,4
#
# venkatesh,ameerpet,59019,5
#
# sai,KPHB,74974,6
#
# venkatesh,ameerpet,69280,7
#
# venkatesh,sr nagar,88184,8
#
# venkatesh,KPHB,78754,9
#
# priyanka,KPHB,72143,10
#
# sai,uppal,69439,11
#
# venkatesh,sr nagar,60704,12
#
# venkatesh,ameerpet,77010,13
#
# venkatesh,sr nagar,76201,14
#
# amar,ameerpet,50280,15
#
# sai,devender nagar,60386,16
#
# amar,KPHB,88387,17
#
# priyanka,devender nagar,84606,18
#
# priyanka,devender nagar,87318,19
#
# samba,KPHB,86656,20
#
# sai,sr nagar,52393,21
#
# venkatesh,devender nagar,77989,22
#
# samba,devender nagar,62932,23
#
# sai,sr nagar,77047,24
#
# samba,devender nagar,86786,25
#
# venkatesh,devender nagar,68756,26
#
# samba,sr nagar,65534,27
#
# samba,sr nagar,59173,28
#
# amar,KPHB,56054,29
#
# venkatesh,devender nagar,88017,30
#
# amar,sr nagar,51838,31
#
# ...

# %%
f=open("data.csv")
for row in f:
    print(row)
# Out:
# name,address,sal,id
#
# sai,ameerpet,50735,0
#
# venkatesh,ameerpet,59921,1
#
# venkatesh,KPHB,61532,2
#
# samba,devender nagar,55481,3
#
# amar,ameerpet,82344,4
#
# venkatesh,ameerpet,59019,5
#
# sai,KPHB,74974,6
#
# venkatesh,ameerpet,69280,7
#
# venkatesh,sr nagar,88184,8
#
# venkatesh,KPHB,78754,9
#
# priyanka,KPHB,72143,10
#
# sai,uppal,69439,11
#
# venkatesh,sr nagar,60704,12
#
# venkatesh,ameerpet,77010,13
#
# venkatesh,sr nagar,76201,14
#
# amar,ameerpet,50280,15
#
# sai,devender nagar,60386,16
#
# amar,KPHB,88387,17
#
# priyanka,devender nagar,84606,18
#
# priyanka,devender nagar,87318,19
#
# samba,KPHB,86656,20
#
# sai,sr nagar,52393,21
#
# venkatesh,devender nagar,77989,22
#
# samba,devender nagar,62932,23
#
# sai,sr nagar,77047,24
#
# samba,devender nagar,86786,25
#
# venkatesh,devender nagar,68756,26
#
# samba,sr nagar,65534,27
#
# samba,sr nagar,59173,28
#
# amar,KPHB,56054,29
#
# venkatesh,devender nagar,88017,30
#
# amar,sr nagar,51838,31
#
# ...

# %%
f=open("data.csv")
for row in f:
    print(row.split(","))
    break
# Out:
# ['name', 'address', 'sal', 'id\n']

# %%
f=open("data.csv")
for row in f:
    print(row.split(",")[-2])
    break
# Out:
# sal

# %%
f=open("data.csv")
data = [row.split(",")[-2] for row in f]
print(data)
# Out:
# ['sal', '50735', '59921', '61532', '55481', '82344', '59019', '74974', '69280', '88184', '78754', '72143', '69439', '60704', '77010', '76201', '50280', '60386', '88387', '84606', '87318', '86656', '52393', '77989', '62932', '77047', '86786', '68756', '65534', '59173', '56054', '88017', '51838', '52899', '52593', '86597', '59738', '75944', '79227', '59085', '67321', '87175', '60858', '74052', '59238', '55989', '80825', '67156', '55879', '88972', '86995', '55407', '69881', '62896', '71539', '58124', '55306', '50602', '60843', '62279', '68776', '59604', '70372', '86553', '68831', '81739', '82356', '55044', '59703', '72627', '59592', '88110', '85524', '83680', '55231', '74177', '70836', '53131', '55504', '53315', '55257', '77207', '88957', '84625', '75012', '73895', '81870', '58863', '63041', '87832', '86508', '89118', '84941', '88779', '54659', '63111', '75181', '52509', '59965', '50166', '72104', '85735', '61110', '68170', '63149', '76080', '62634', '85513', '74459', '59227', '79072', 
# ...

# %%
f=open("data.csv")
data = [row.split(",")[-2] for row in f]
data.pop(0)
print(data)
# Out:
# ['50735', '59921', '61532', '55481', '82344', '59019', '74974', '69280', '88184', '78754', '72143', '69439', '60704', '77010', '76201', '50280', '60386', '88387', '84606', '87318', '86656', '52393', '77989', '62932', '77047', '86786', '68756', '65534', '59173', '56054', '88017', '51838', '52899', '52593', '86597', '59738', '75944', '79227', '59085', '67321', '87175', '60858', '74052', '59238', '55989', '80825', '67156', '55879', '88972', '86995', '55407', '69881', '62896', '71539', '58124', '55306', '50602', '60843', '62279', '68776', '59604', '70372', '86553', '68831', '81739', '82356', '55044', '59703', '72627', '59592', '88110', '85524', '83680', '55231', '74177', '70836', '53131', '55504', '53315', '55257', '77207', '88957', '84625', '75012', '73895', '81870', '58863', '63041', '87832', '86508', '89118', '84941', '88779', '54659', '63111', '75181', '52509', '59965', '50166', '72104', '85735', '61110', '68170', '63149', '76080', '62634', '85513', '74459', '59227', '79072', '74646'
# ...

# %%
l=[1,2,3,4]
print(sum(l)/len(l))
# Out:
# 2.5

# %%
l=['1','2']
sum(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-d86efe70ad17> in <module>
#       1 l=['1','2']
# ----> 2 sum(l)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
f=open("data.csv")
data = [row.split(",")[-2] for row in f]
data.pop(0)
data = list(map(int,data))
print(data[0:10])
# Out:
# [50735, 59921, 61532, 55481, 82344, 59019, 74974, 69280, 88184, 78754]

# %%
f=open("data.csv")
data = [row.split(",")[-2] for row in f]
data.pop(0)
data = list(map(int,data))
print(sum(data)/len(data))
# Out:
# 70442.453

# %%
f=open("data.csv")
act_data = [row.split(",")[-2] for row in f]
act_data.pop(0)
data = list(map(int,act_data))
avg_sal = sum(data)/len(data)
above=[]
below=[]
def fun(row):
    if not row:
        return 
    l=row.split(",")
    sal=l[-2]
    if sal.isdigit():
        sal=int(sal)
    else:
        return 
    name=l[0]
    if sal>=avg_sal:
        above.append(name)
    else:
        below.append(name)
f.seek(0)
list(map(fun,f))
print(above)
print("*"*20)
print(below)
# Out:
# ['amar', 'sai', 'venkatesh', 'venkatesh', 'priyanka', 'venkatesh', 'venkatesh', 'amar', 'priyanka', 'priyanka', 'samba', 'venkatesh', 'sai', 'samba', 'venkatesh', 'priyanka', 'priyanka', 'amar', 'priyanka', 'venkatesh', 'priyanka', 'sai', 'priyanka', 'venkatesh', 'sai', 'samba', 'venkatesh', 'samba', 'priyanka', 'venkatesh', 'venkatesh', 'sai', 'venkatesh', 'venkatesh', 'priyanka', 'samba', 'samba', 'amar', 'amar', 'priyanka', 'venkatesh', 'priyanka', 'venkatesh', 'amar', 'venkatesh', 'amar', 'venkatesh', 'samba', 'priyanka', 'amar', 'priyanka', 'amar', 'priyanka', 'priyanka', 'samba', 'sai', 'samba', 'samba', 'priyanka', 'sai', 'priyanka', 'venkatesh', 'amar', 'samba', 'amar', 'priyanka', 'amar', 'amar', 'venkatesh', 'venkatesh', 'amar', 'venkatesh', 'amar', 'priyanka', 'venkatesh', 'priyanka', 'sai', 'venkatesh', 'samba', 'sai', 'sai', 'sai', 'priyanka', 'venkatesh', 'venkatesh', 'sai', 'venkatesh', 'samba', 'priyanka', 'venkatesh', 'samba', 'amar', 'amar', 'sai', 'amar', 'samba', 
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
print(df.head())
# Out:
#         name         address    sal  id
# 0        sai        ameerpet  50735   0
# 1  venkatesh        ameerpet  59921   1
# 2  venkatesh            KPHB  61532   2
# 3      samba  devender nagar  55481   3
# 4       amar        ameerpet  82344   4

# %%
df = pd.read_csv("data.csv")
df.columns
# Out:
# Index(['name', 'address', 'sal', 'id'], dtype='object')

# %%
df.sal
# Out:
# 0      50735
# 1      59921
# 2      61532
# 3      55481
# 4      82344
# 5      59019
# 6      74974
# 7      69280
# 8      88184
# 9      78754
# 10     72143
# 11     69439
# 12     60704
# 13     77010
# 14     76201
# 15     50280
# 16     60386
# 17     88387
# 18     84606
# 19     87318
# 20     86656
# 21     52393
# 22     77989
# 23     62932
# 24     77047
# 25     86786
# 26     68756
# 27     65534
# 28     59173
# 29     56054
#        ...
# 970    85168
# 971    64421
# 972    54199
# 973    77948
# 974    74459
# 975    68210
# 976    79083
# 977    81871
# 978    87816
# 979    57613
# 980    61036
# 981    68550
# 982    52349
# 983    71169
# 984    89442
# 985    77981
# 986    88701
# 987    59412
# 988    73017
# 989    69253
# 990    54703
# 991    75027
# 992    88267
# 993    70187
# 994    89809
# 995    82634
# 996    77214
# 997    59832
# 998    85681
# 999    60942
# Name: sal, Length: 1000, dtype: int64

# %%
df.sal.mean()
# Out:
# 70442.453

# %%
df.describe()
# Out:
#                 sal           id
# count   1000.000000  1000.000000
# mean   70442.453000   499.500000
# std    11782.685365   288.819436
# min    50025.000000     0.000000
# 25%    60017.250000   249.750000
# 50%    70418.500000   499.500000
# 75%    81259.500000   749.250000
# max    89994.000000   999.000000

# %%
df[df.sal<=df.sal.mean()]
# Out:
#           name         address    sal   id
# 0          sai        ameerpet  50735    0
# 1    venkatesh        ameerpet  59921    1
# 2    venkatesh            KPHB  61532    2
# 3        samba  devender nagar  55481    3
# 5    venkatesh        ameerpet  59019    5
# 7    venkatesh        ameerpet  69280    7
# 11         sai           uppal  69439   11
# 12   venkatesh        sr nagar  60704   12
# 15        amar        ameerpet  50280   15
# 16         sai  devender nagar  60386   16
# 21         sai        sr nagar  52393   21
# 23       samba  devender nagar  62932   23
# 26   venkatesh  devender nagar  68756   26
# 27       samba        sr nagar  65534   27
# 28       samba        sr nagar  59173   28
# 29        amar            KPHB  56054   29
# 31        amar        sr nagar  51838   31
# 32    priyanka        sr nagar  52899   32
# 33       samba            KPHB  52593   33
# 35        amar  devender nagar  59738   35
# 38   venkatesh           uppal  59085   38
# ...

# %%
df[df.address=="KPHB"]
# Out:
#           name address    sal   id
# 2    venkatesh    KPHB  61532    2
# 6          sai    KPHB  74974    6
# 9    venkatesh    KPHB  78754    9
# 10    priyanka    KPHB  72143   10
# 17        amar    KPHB  88387   17
# 20       samba    KPHB  86656   20
# 29        amar    KPHB  56054   29
# 33       samba    KPHB  52593   33
# 44       samba    KPHB  55989   44
# 45    priyanka    KPHB  80825   45
# 50         sai    KPHB  55407   50
# 51    priyanka    KPHB  69881   51
# 62         sai    KPHB  86553   62
# 65   venkatesh    KPHB  82356   65
# 66       samba    KPHB  55044   66
# 71   venkatesh    KPHB  85524   71
# 72   venkatesh    KPHB  83680   72
# 78       samba    KPHB  53315   78
# 79         sai    KPHB  55257   79
# 85        amar    KPHB  81870   85
# 87       samba    KPHB  63041   87
# 89   venkatesh    KPHB  86508   89
# 101   priyanka    KPHB  61110  101
# 102       amar    KPHB  68170  102
# 104      samba    KPHB  76080  104
# 118      samba    KPHB  50679  118
# ...

# %%
df.groupby("address").sum()
# Out:
#                      sal      id
# address
# KPHB            15102262  105085
# ameerpet        14230053  103084
# devender nagar  12484163   87736
# sr nagar        14208375  100403
# uppal           14417600  103192

# %%
df.groupby("address").sum().plot()

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
df.groupby("address").sum().plot()
plt.show()

# %%
df.groupby("address").sum().plot(kind="bar")
plt.show()

# %%
import json
f=open("data.json","w")
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
json.dump(persons,f)
f.close()

# %%
import yaml
f=open("data.yaml","w")
persons = [{"name":"jay","age":3},{"name":"vedha","age":2},{"name":"dhana","age":18}]
yaml.dump(persons,f)
f.close()

# %%
f=open("data.yaml","r")
data = yaml.load(f)
print(data,type(data))
# Out:
# [{'age': 3, 'name': 'jay'}, {'age': 2, 'name': 'vedha'}, {'age': 18, 'name': 'dhana'}] <class 'list'>
# /home/khyaathipyndj/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
f=open("file.jpg","rb")
data=f.read()
f=open("file_bkp.jpg","wb")
f.write(data)
f.close()
